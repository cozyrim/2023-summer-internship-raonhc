# %% [markdown]
# <a href="https://colab.research.google.com/github/cozyrim/Summer-Field-Practice/blob/master/%EC%9E%90%EB%8F%99%EC%B0%A8%EB%B2%88%ED%98%B8%ED%8C%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 많은 양의 연산을 빠르게 처리

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# # YOLOv8 설치

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-02a9766c61a0> in <cell line: 8>()
#       6 display.clear_output()
#       7
# ----> 8 import ultralytics
#       9 ultralytics.checks()
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/__init__.py in <module>
#       3 __version__ = "8.0.20"
#       4
# ----> 5 from ultralytics.yolo.engine.model import YOLO
#       6 from ultralytics.yolo.utils import ops
#       7 from ultralytics.yolo.utils.checks import check_yolo as checks
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       2
# ----> 3 from . import v8
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/v8/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       2
# ----> 3 from ultralytics.yolo.v8 import classify, detect, segment
#       4
#       5 __all__ = ["classify", "segment", "detect"]
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/v8/classify/__init__.py in <module>
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       2
# ----> 3 from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#       4 from ultralytics.yolo.v8.classify.train import ClassificationTrainer, train
#       5 from ultralytics.yolo.v8.classify.val import ClassificationValidator, val
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/v8/classify/predict.py in <module>
#       2 import sys
#       3
# ----> 4 import torch
#       5
#       6 from ultralytics.yolo.engine.predictor import BasePredictor
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     455     raise  # If __file__ is not None the cause is unknown, so just re-raise.
#     456
# --> 457 for name in dir(_C):
#     458     if name[0] != '_' and not name.endswith('Base'):
#     459         __all__.append(name)
#
# NameError: name '_C' is not defined

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

print(type(model.names), len(model.names))
print(model.names)

# %% [markdown]
# # robotflow 설치 및 데이터셋 불러오기

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uKrmw84paJUWa2J01LRn")
project = rf.workspace("mayank-tripathi-h4ov1").project("car_number-ywn73")
dataset = project.version(2).download("yolov8")

# %%
model.train(data='/content/CAR_NUMBER-2/data.yaml', epochs=50, patience=30, batch=64, imgsz=640)

# %%
results = model.predict(source='/content/CAR_NUMBER-2/test/images/', save=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
results = model.predict(source='/content/Driving Downtown.mp4', save=True)
